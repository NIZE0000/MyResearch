# %%
import numpy as np

# define mean vector and covariance matrix
mu = np.array([2, 3])
cov = np.array([[1, 0.5], [0.5, 4]])

# generate 1000 random samples
samples = np.random.multivariate_normal(mu, cov, size=1000)

# plot samples
import matplotlib.pyplot as plt
print(samples)
plt.scatter(samples[:, 0], samples[:, 1])
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# [[2.0145823  2.59436042]
#  [3.34685533 5.63885389]
#  [1.11871017 1.62361832]
#  ...
#  [1.36840542 1.2619822 ]
#  [2.84231799 1.99414751]
#  [2.18804943 6.29935016]]
